# %%
from sargan_models import SARGAN
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
from sar_utilities import add_gaussian_noise
from cifar_helper import get_data, chunks
import random
import skimage.measure as ski_me

# %%
#get test batches from cifar dataset
test_filename = "test_batch"
test_imgs, test_classes = get_data(test_filename)
test_imgs = test_imgs.astype('float32')
BATCH_SIZE = 50
test_batches = np.array(list(chunks(test_imgs, BATCH_SIZE)))
# test_batches = test_imgs
NOISE_STD = 0.1

# params to recover the trained model
img_size = (32,32,3)
DATA_PATH = "/scratch/hle/data/"
model_trained_epoch = 1
model_path_test = os.path.join(DATA_PATH,
                               "trained_models/cifar_10_gaussian_corrupted/",
                               "cifar_10_gaussian_corrupted_model_{}.ckpt".format(model_trained_epoch))
model = SARGAN(img_size, BATCH_SIZE, img_channel=3)
saver = tf.train.Saver()

# tensorflow config
gpu = "3"
gpu_options = tf.GPUOptions(allow_growth=True, visible_device_list=gpu)
config=tf.ConfigProto(gpu_options=gpu_options)

# some display of original, corrupted and recovered
# fig=plt.figure(figsize=(8, 100))
# columns = 3
# rows = 50

# error calculation
sum_psnr = 0
with tf.Session(config=config) as sess:
    saver.restore(sess, model_path_test)
    for i in range(200):
        #get 1 batch of size BATCH_SIZE and then corrupt it
        batch = test_batches[i]
        print("batch range %s, %s" % (np.amax(batch), np.amin(batch)))
        corrupted_batch = np.array([add_gaussian_noise(image, sd=NOISE_STD) for image in batch])
        print("corrupted batch range %s, %s" % (np.amax(corrupted_batch), np.amin(corrupted_batch)))
        gen_imgs = sess.run(model.gen_img, feed_dict={model.image:batch, model.cond:corrupted_batch})
        print("recovered batch range %s, %s" % (np.amax(gen_imgs), np.amin(gen_imgs)))
#         j = 1
        for k in range(len(batch)):
#             fig.add_subplot(rows, columns, j)
            img = batch[k]
#             plt.imshow(img)
#             j+=1
#             fig.add_subplot(rows, columns, j)
#             corrupted_img = corrupted_batch[k]
#             plt.imshow(corrupted_img)
#             j+=1
#             fig.add_subplot(rows, columns, j)
            recovered_img = gen_imgs[k]
#             plt.imshow(recovered_img)
#             j+=1
            sum_psnr += ski_me.compare_psnr(img, recovered_img)
            
    plt.show()
    print(sum_psnr/10000)
# Out:
# Loading data: /scratch/hle/cifar-10-batches-py/test_batch
# INFO:tensorflow:Restoring parameters from /scratch/hle/data/trained_models/cifar_10_gaussian_corrupted/cifar_10_gaussian_corrupted_model_1.ckpt
# batch range 1.0, 0.0
# corrupted batch range 1.31610079622, -0.340876273604
# recovered batch range 1.29231, -0.173034
# batch range 1.0, 0.0
# corrupted batch range 1.36744246215, -0.30796166186
# recovered batch range 1.30428, -0.0624188
# batch range 1.0, 0.0
# corrupted batch range 1.37450754834, -0.351406407982
# recovered batch range 1.23362, -0.153712
# batch range 1.0, 0.0
# corrupted batch range 1.3394379686, -0.375399637162
# recovered batch range 1.23425, -0.0991922
# batch range 1.0, 0.0
# corrupted batch range 1.37437590501, -0.306593283681
# recovered batch range 1.21276, -0.0761571
# batch range 1.0, 0.0
# corrupted batch range 1.38590277736, -0.366631001712
# recovered batch range 1.3419, -0.121686
# batch range 1.0, 0.0
# corrupted batch range 1.29749136138, -0.337660410235
# recovered batch range 1.14086, -0.101779
# batch range 1.0, 0.0
# corrupted batch range 1.3784150636, -0.281766030041
# recovered batch range 1.2439, -0.130686
# batch range 1.0, 0.0
# corrupted batch range 1.35817132258, -0.334313007995
# recovered batch range 1.28391, -0.148531
# batch range 1.0, 0.0
# corrupted batch range 1.3494050718, -0.288061086676
# recovered batch range 1.26631, -0.0741012
# batch range 1.0, 0.0
# corrupted batch range 1.35400666996, -0.336363756048
# recovered batch range 1.18203, -0.0723187
# batch range 1.0, 0.0
# corrupted batch range 1.33978279115, -0.388014760034
# recovered batch range 1.20546, -0.124636
# batch range 1.0, 0.0
# corrupted batch range 1.45525338564, -0.314615907899
# recovered batch range 1.24237, -0.161699
# batch range 1.0, 0.0
# corrupted batch range 1.36357974075, -0.34533532712
# recovered batch range 1.25134, -0.113514
# batch range 1.0, 0.0
# corrupted batch range 1.27593397106, -0.326843435585
# recovered batch range 1.20088, -0.125536
# batch range 1.0, 0.0
# corrupted batch range 1.40671153342, -0.318785646843
# recovered batch range 1.22367, -0.119384
# batch range 1.0, 0.0
# corrupted batch range 1.40453521071, -0.325149796328
# recovered batch range 1.34844, -0.121929
# batch range 1.0, 0.0
# corrupted batch range 1.36730024557, -0.325678777933
# recovered batch range 1.16943, -0.0601482
# batch range 1.0, 0.0
# corrupted batch range 1.36288006887, -0.318108836949
# recovered batch range 1.16813, -0.164167
# batch range 1.0, 0.0
# corrupted batch range 1.32675053944, -0.343979912027
# recovered batch range 1.16889, -0.145999
# batch range 1.0, 0.0
# corrupted batch range 1.36556844263, -0.325806930377
# recovered batch range 1.38788, -0.162319
# batch range 1.0, 0.0
# corrupted batch range 1.3175313249, -0.376800873051
# recovered batch range 1.24848, -0.124213
# batch range 1.0, 0.0
# corrupted batch range 1.37287960596, -0.295242709925
# recovered batch range 1.23951, -0.0755934
# batch range 1.0, 0.0
# corrupted batch range 1.36289524857, -0.332403569255
# recovered batch range 1.21143, -0.148032
# batch range 1.0, 0.0
# corrupted batch range 1.34100255136, -0.339437821261
# recovered batch range 1.2101, -0.120548
# batch range 1.0, 0.0
# corrupted batch range 1.40243077905, -0.392316567976
# recovered batch range 1.18137, -0.110633
# batch range 1.0, 0.0
# corrupted batch range 1.33870960184, -0.409931595648
# recovered batch range 1.27431, -0.108097
# batch range 1.0, 0.0
# corrupted batch range 1.37606291405, -0.285647546431
# recovered batch range 1.28439, -0.123953
# batch range 1.0, 0.0
# corrupted batch range 1.33478699111, -0.348802105941
# recovered batch range 1.24212, -0.196217
# batch range 1.0, 0.0
# corrupted batch range 1.35344390729, -0.325616752497
# recovered batch range 1.28974, -0.0859207
# batch range 1.0, 0.0
# corrupted batch range 1.31569858697, -0.333938561753
# recovered batch range 1.27483, -0.0634357
# batch range 1.0, 0.0
# corrupted batch range 1.34628833964, -0.36931217741
# recovered batch range 1.27694, -0.139829
# batch range 1.0, 0.0
# corrupted batch range 1.3353745499, -0.33352707288
# recovered batch range 1.31239, -0.149162
# batch range 1.0, 0.0
# corrupted batch range 1.3398553779, -0.312635076683
# recovered batch range 1.21681, -0.141745
# batch range 1.0, 0.0
# corrupted batch range 1.31003889078, -0.358012878702
# recovered batch range 1.24101, -0.18735
# batch range 1.0, 0.0
# corrupted batch range 1.33545305874, -0.324217009101
# recovered batch range 1.22898, -0.162011
# batch range 1.0, 0.0
# corrupted batch range 1.36604619467, -0.332953268864
# recovered batch range 1.21704, -0.107925
# batch range 1.0, 0.0
# corrupted batch range 1.35672619787, -0.363552715642
# recovered batch range 1.25087, -0.0950423
# batch range 1.0, 0.0
# corrupted batch range 1.36989579325, -0.315656568358
# recovered batch range 1.28625, -0.107942
# batch range 1.0, 0.0
# corrupted batch range 1.37786536613, -0.384148832251
# recovered batch range 1.19827, -0.147253
# batch range 1.0, 0.0
# corrupted batch range 1.40251794638, -0.41491872389
# recovered batch range 1.24506, -0.0940977
# batch range 1.0, 0.0
# corrupted batch range 1.36441123085, -0.335766633035
# recovered batch range 1.22974, -0.106128
# batch range 1.0, 0.0
# corrupted batch range 1.38774417403, -0.332692128277
# recovered batch range 1.23652, -0.176577
# batch range 1.0, 0.0
# corrupted batch range 1.3485753972, -0.320857648079
# recovered batch range 1.21856, -0.125279
# batch range 1.0, 0.0
# corrupted batch range 1.31070078922, -0.335086302896
# recovered batch range 1.17461, -0.103359
# batch range 1.0, 0.0
# corrupted batch range 1.3357978046, -0.352346987612
# recovered batch range 1.19012, -0.129454
# batch range 1.0, 0.0
# corrupted batch range 1.38419742722, -0.368994966734
# recovered batch range 1.3281, -0.118442
# batch range 1.0, 0.0
# corrupted batch range 1.34347577779, -0.321683783056
# recovered batch range 1.17608, -0.180067
# batch range 1.0, 0.0
# corrupted batch range 1.36895839903, -0.319069665053
# recovered batch range 1.26139, -0.200983
# batch range 1.0, 0.0
# corrupted batch range 1.42327586836, -0.349727556446
# recovered batch range 1.23487, -0.074603
# batch range 1.0, 0.0
# corrupted batch range 1.33284803096, -0.311048043756
# recovered batch range 1.26196, -0.0938304
# batch range 1.0, 0.0
# corrupted batch range 1.38606901796, -0.379546587521
# recovered batch range 1.27572, -0.121181
# batch range 1.0, 0.0
# corrupted batch range 1.34987423643, -0.425268643827
# recovered batch range 1.20029, -0.118574
# batch range 1.0, 0.0
# corrupted batch range 1.35113395843, -0.353586868183
# recovered batch range 1.26347, -0.0504555
# batch range 1.0, 0.0
# corrupted batch range 1.41207085977, -0.368021618372
# recovered batch range 1.2274, -0.0730577
# batch range 1.0, 0.0
# corrupted batch range 1.38011434438, -0.380072272239
# recovered batch range 1.25388, -0.184124
# batch range 1.0, 0.0
# corrupted batch range 1.36921256329, -0.397979807749
# recovered batch range 1.29515, -0.0966743
# batch range 1.0, 0.0
# corrupted batch range 1.35094473986, -0.317804600586
# recovered batch range 1.23311, -0.115303
# batch range 1.0, 0.0
# corrupted batch range 1.32318582012, -0.347212856843
# recovered batch range 1.17417, -0.0755609
# batch range 1.0, 0.0
# corrupted batch range 1.31819152643, -0.294558352187
# recovered batch range 1.2961, -0.0827072
# batch range 1.0, 0.0
# corrupted batch range 1.31989909143, -0.341025571115
# recovered batch range 1.3006, -0.101562
# batch range 1.0, 0.0
# corrupted batch range 1.3456123269, -0.330047438731
# recovered batch range 1.2134, -0.189021
# batch range 1.0, 0.0
# corrupted batch range 1.36583111723, -0.364892309863
# recovered batch range 1.24631, -0.132185
# batch range 1.0, 0.0
# corrupted batch range 1.36743306985, -0.329050148565
# recovered batch range 1.23884, -0.0672192
# batch range 1.0, 0.0
# corrupted batch range 1.36428044026, -0.365193254346
# recovered batch range 1.20046, -0.108023
# batch range 1.0, 0.0
# corrupted batch range 1.33168123746, -0.377598788255
# recovered batch range 1.21766, -0.0694669
# batch range 1.0, 0.0
# corrupted batch range 1.38571973123, -0.369067101793
# recovered batch range 1.2675, -0.0816551
# batch range 1.0, 0.0
# corrupted batch range 1.33788814548, -0.412813704212
# recovered batch range 1.18869, -0.143366
# batch range 1.0, 0.0
# corrupted batch range 1.31312316993, -0.340777017643
# recovered batch range 1.21755, -0.141286
# batch range 1.0, 0.0
# corrupted batch range 1.36888530212, -0.326063477742
# recovered batch range 1.20463, -0.0899133
# batch range 1.0, 0.0
# corrupted batch range 1.41114218205, -0.278628347988
# recovered batch range 1.18003, -0.0580806
# batch range 1.0, 0.0
# corrupted batch range 1.3761543331, -0.334248219215
# recovered batch range 1.19872, -0.0966075
# batch range 1.0, 0.0
# corrupted batch range 1.34884797055, -0.329398942328
# recovered batch range 1.21492, -0.154888
# batch range 1.0, 0.0
# corrupted batch range 1.34200211611, -0.278087847701
# recovered batch range 1.27202, -0.127794
# batch range 1.0, 0.0
# corrupted batch range 1.38352083306, -0.390971290348
# recovered batch range 1.23998, -0.113122
# batch range 1.0, 0.0
# corrupted batch range 1.37233380328, -0.323208630365
# recovered batch range 1.24186, -0.0571087
# batch range 1.0, 0.0
# corrupted batch range 1.35514051474, -0.33778471451
# recovered batch range 1.19607, -0.101265
# batch range 1.0, 0.0
# corrupted batch range 1.35889213885, -0.308183784202
# recovered batch range 1.21188, -0.0871722
# batch range 1.0, 0.0
# corrupted batch range 1.35940018331, -0.360680830595
# recovered batch range 1.2169, -0.0897703
# batch range 1.0, 0.0
# corrupted batch range 1.33686776971, -0.337563171346
# recovered batch range 1.18949, -0.112977
# batch range 1.0, 0.0
# corrupted batch range 1.39530651775, -0.324215147804
# recovered batch range 1.22028, -0.105749
# batch range 1.0, 0.0
# corrupted batch range 1.33458446003, -0.305256195705
# recovered batch range 1.21795, -0.132692
# batch range 1.0, 0.0
# corrupted batch range 1.3435495977, -0.382456148814
# recovered batch range 1.27385, -0.0532487
# batch range 1.0, 0.0
# corrupted batch range 1.3101305935, -0.424795586096
# recovered batch range 1.2437, -0.110929
# batch range 1.0, 0.0
# corrupted batch range 1.43669448297, -0.346108291033
# recovered batch range 1.23507, -0.1461
# batch range 1.0, 0.0
# corrupted batch range 1.31616871263, -0.331474211716
# recovered batch range 1.2102, -0.223942
# batch range 1.0, 0.0
# corrupted batch range 1.3344222486, -0.347048676588
# recovered batch range 1.20997, -0.0838024
# batch range 1.0, 0.0
# corrupted batch range 1.37916463904, -0.349846427402
# recovered batch range 1.2594, -0.0878917
# batch range 1.0, 0.0
# corrupted batch range 1.34198089841, -0.327924111274
# recovered batch range 1.24263, -0.210229
# batch range 1.0, 0.0
# corrupted batch range 1.34561166352, -0.34244855651
# recovered batch range 1.48088, -0.143872
# batch range 1.0, 0.0
# corrupted batch range 1.37121369481, -0.320225447169
# recovered batch range 1.29856, -0.136914
# batch range 1.0, 0.0
# corrupted batch range 1.3920436811, -0.345045625329
# recovered batch range 1.24883, -0.0862995
# batch range 1.0, 0.0
# corrupted batch range 1.34930648738, -0.324134050635
# recovered batch range 1.28236, -0.16636
# batch range 1.0, 0.0
# corrupted batch range 1.33584893909, -0.317845282652
# recovered batch range 1.28327, -0.0699434
# batch range 1.0, 0.0
# corrupted batch range 1.33672668578, -0.36363502495
# recovered batch range 1.20386, -0.106217
# batch range 1.0, 0.0
# corrupted batch range 1.37041228669, -0.338510922086
# recovered batch range 1.22259, -0.0796085
# batch range 1.0, 0.0
# corrupted batch range 1.32067805089, -0.348773833122
# recovered batch range 1.28086, -0.1003
# batch range 1.0, 0.0
# corrupted batch range 1.33377032708, -0.366149182741
# recovered batch range 1.18936, -0.157579
# batch range 1.0, 0.0
# corrupted batch range 1.35792145948, -0.332508252585
# recovered batch range 1.24958, -0.103994
# batch range 1.0, 0.0
# corrupted batch range 1.35706019915, -0.344365691003
# recovered batch range 1.24785, -0.0889824
# batch range 1.0, 0.0
# corrupted batch range 1.36842404849, -0.275122649024
# recovered batch range 1.2513, -0.0684989
# batch range 1.0, 0.0
# corrupted batch range 1.33909295958, -0.328050070004
# recovered batch range 1.26822, -0.0981829
# batch range 1.0, 0.0
# corrupted batch range 1.32068954326, -0.358074791947
# recovered batch range 1.18341, -0.115085
# batch range 1.0, 0.0
# corrupted batch range 1.33210037673, -0.279568847734
# recovered batch range 1.23258, -0.0717493
# batch range 1.0, 0.0
# corrupted batch range 1.32999442254, -0.292370692044
# recovered batch range 1.23769, -0.111649
# batch range 1.0, 0.0
# corrupted batch range 1.37998439406, -0.328637347208
# recovered batch range 1.28314, -0.178125
# batch range 1.0, 0.0
# corrupted batch range 1.37854483849, -0.289903633732
# recovered batch range 1.30053, -0.105623
# batch range 1.0, 0.0
# corrupted batch range 1.34514352022, -0.330035518617
# recovered batch range 1.3031, -0.135614
# batch range 1.0, 0.0
# corrupted batch range 1.34633654742, -0.29948090356
# recovered batch range 1.26192, -0.105824
# batch range 1.0, 0.0
# corrupted batch range 1.35668461474, -0.384284799648
# recovered batch range 1.27081, -0.165059
# batch range 1.0, 0.0
# corrupted batch range 1.44522432473, -0.321130127672
# recovered batch range 1.20014, -0.142455
# batch range 1.0, 0.0
# corrupted batch range 1.3506286941, -0.366083846826
# recovered batch range 1.24144, -0.0692725
# batch range 1.0, 0.0
# corrupted batch range 1.35894503962, -0.321196358152
# recovered batch range 1.23698, -0.146586
# batch range 1.0, 0.0
# corrupted batch range 1.32033394893, -0.285353694255
# recovered batch range 1.17426, -0.0856442
# batch range 1.0, 0.0
# corrupted batch range 1.35695833603, -0.372222960436
# recovered batch range 1.24864, -0.124159
# batch range 1.0, 0.0
# corrupted batch range 1.3629236774, -0.313100431596
# recovered batch range 1.208, -0.144766
# batch range 1.0, 0.0
# corrupted batch range 1.36244760518, -0.334668095959
# recovered batch range 1.25751, -0.0869776
# batch range 1.0, 0.0
# corrupted batch range 1.37155244647, -0.324874349438
# recovered batch range 1.20826, -0.112247
# batch range 1.0, 0.0
# corrupted batch range 1.36553042959, -0.365378287461
# recovered batch range 1.19618, -0.124956
# batch range 1.0, 0.0
# corrupted batch range 1.37684015982, -0.320725786574
# recovered batch range 1.23759, -0.0501289
# batch range 1.0, 0.0
# corrupted batch range 1.3732232023, -0.299217819406
# recovered batch range 1.22336, -0.185168
# batch range 1.0, 0.0
# corrupted batch range 1.34929450132, -0.447901862535
# recovered batch range 1.26542, -0.114994
# batch range 1.0, 0.0
# corrupted batch range 1.39901608257, -0.321790713194
# recovered batch range 1.25249, -0.0709947
# batch range 1.0, 0.0
# corrupted batch range 1.37765510266, -0.390919810706
# recovered batch range 1.19664, -0.186454
# batch range 1.0, 0.0
# corrupted batch range 1.34252794383, -0.42624749576
# recovered batch range 1.29606, -0.149066
# batch range 1.0, 0.0
# corrupted batch range 1.30950007973, -0.413498252323
# recovered batch range 1.25317, -0.0846848
# batch range 1.0, 0.0
# corrupted batch range 1.32694085755, -0.385913587725
# recovered batch range 1.16615, -0.155655
# batch range 1.0, 0.0
# corrupted batch range 1.37071357223, -0.335654260968
# recovered batch range 1.34403, -0.061911
# batch range 1.0, 0.0
# corrupted batch range 1.3187728031, -0.336323298354
# recovered batch range 1.24161, -0.0685868
# batch range 1.0, 0.0
# corrupted batch range 1.36335346687, -0.339319655977
# recovered batch range 1.2235, -0.0860521
# batch range 1.0, 0.0
# corrupted batch range 1.3892077925, -0.381718322624
# recovered batch range 1.24826, -0.0941245
# batch range 1.0, 0.0
# corrupted batch range 1.41032759015, -0.344606126628
# recovered batch range 1.26111, -0.190689
# batch range 1.0, 0.0
# corrupted batch range 1.4322554858, -0.317648046873
# recovered batch range 1.15112, -0.143263
# batch range 1.0, 0.0
# corrupted batch range 1.41386480903, -0.373949234364
# recovered batch range 1.27493, -0.122611
# batch range 1.0, 0.0
# corrupted batch range 1.3713653167, -0.323047123347
# recovered batch range 1.26645, -0.151294
# batch range 1.0, 0.0
# corrupted batch range 1.31129274291, -0.288849723214
# recovered batch range 1.29593, -0.147618
# batch range 1.0, 0.0
# corrupted batch range 1.43829140592, -0.310945312238
# recovered batch range 1.17609, -0.0767416
# batch range 1.0, 0.0
# corrupted batch range 1.34628285851, -0.312308616567
# recovered batch range 1.23966, -0.124134
# batch range 1.0, 0.0
# corrupted batch range 1.35921925353, -0.343490505829
# recovered batch range 1.28031, -0.0674803
# batch range 1.0, 0.0
# corrupted batch range 1.43824311525, -0.30919946793
# recovered batch range 1.25521, -0.100412
# batch range 1.0, 0.0
# corrupted batch range 1.36833956667, -0.354449009779
# recovered batch range 1.25561, -0.0771536
# batch range 1.0, 0.0
# corrupted batch range 1.33248000557, -0.293822907218
# recovered batch range 1.14771, -0.124005
# batch range 1.0, 0.0
# corrupted batch range 1.40903042802, -0.320928619787
# recovered batch range 1.21197, -0.182687
# batch range 1.0, 0.0
# corrupted batch range 1.32076256244, -0.292070401122
# recovered batch range 1.24847, -0.12262
# batch range 1.0, 0.0
# corrupted batch range 1.32641104301, -0.370664769834
# recovered batch range 1.31115, -0.135955
# batch range 1.0, 0.0
# corrupted batch range 1.32180313577, -0.389910583033
# recovered batch range 1.29853, -0.125813
# batch range 1.0, 0.0
# corrupted batch range 1.31421433607, -0.31692957923
# recovered batch range 1.31032, -0.107304
# batch range 1.0, 0.0
# corrupted batch range 1.36523652581, -0.351716162714
# recovered batch range 1.24568, -0.217284
# batch range 1.0, 0.0
# corrupted batch range 1.36926963575, -0.334044301144
# recovered batch range 1.20536, -0.138314
# batch range 1.0, 0.0
# corrupted batch range 1.36212021382, -0.358366213018
# recovered batch range 1.37131, -0.181312
# batch range 1.0, 0.0
# corrupted batch range 1.35064514609, -0.309517201339
# recovered batch range 1.199, -0.180304
# batch range 1.0, 0.0
# corrupted batch range 1.37465887184, -0.303866696533
# recovered batch range 1.20516, -0.0965576
# batch range 1.0, 0.0
# corrupted batch range 1.33889304224, -0.314465754469
# recovered batch range 1.20451, -0.0818373
# batch range 1.0, 0.0
# corrupted batch range 1.34681161723, -0.335430415466
# recovered batch range 1.21666, -0.126638
# batch range 1.0, 0.0
# corrupted batch range 1.40242447214, -0.33736725212
# recovered batch range 1.28959, -0.0693252
# batch range 1.0, 0.0
# corrupted batch range 1.34372544473, -0.31027601466
# recovered batch range 1.31846, -0.19362
# batch range 1.0, 0.0
# corrupted batch range 1.33548533235, -0.33181796364
# recovered batch range 1.23309, -0.111512
# batch range 1.0, 0.0
# corrupted batch range 1.33346308155, -0.395714981995
# recovered batch range 1.24449, -0.0942732
# batch range 1.0, 0.0
# corrupted batch range 1.34426346169, -0.317098985662
# recovered batch range 1.26128, -0.0736304
# batch range 1.0, 0.0
# corrupted batch range 1.36133608151, -0.335024299482
# recovered batch range 1.19661, -0.0870308
# batch range 1.0, 0.0
# corrupted batch range 1.37428216564, -0.348750479315
# recovered batch range 1.22583, -0.13669
# batch range 1.0, 0.0
# corrupted batch range 1.30743497507, -0.369032099829
# recovered batch range 1.19404, -0.0766887
# batch range 1.0, 0.0
# corrupted batch range 1.41196612983, -0.327322488804
# recovered batch range 1.19233, -0.0525792
# batch range 1.0, 0.0
# corrupted batch range 1.37170784934, -0.328166617008
# recovered batch range 1.2808, -0.124135
# batch range 1.0, 0.0
# corrupted batch range 1.3447922857, -0.41849667845
# recovered batch range 1.17792, -0.0746757
# batch range 1.0, 0.0
# corrupted batch range 1.33398594353, -0.319362253959
# recovered batch range 1.21239, -0.13657
# batch range 1.0, 0.0
# corrupted batch range 1.31163013892, -0.357870219961
# recovered batch range 1.21409, -0.128175
# batch range 1.0, 0.0
# corrupted batch range 1.40337862742, -0.36667650415
# recovered batch range 1.25233, -0.118114
# batch range 1.0, 0.0
# corrupted batch range 1.41109111358, -0.385820470081
# recovered batch range 1.24134, -0.165644
# batch range 1.0, 0.0
# corrupted batch range 1.37947932909, -0.338535272746
# recovered batch range 1.2353, -0.178588
# batch range 1.0, 0.0
# corrupted batch range 1.37760608901, -0.325741415204
# recovered batch range 1.22625, -0.143492
# batch range 1.0, 0.0
# corrupted batch range 1.3392894473, -0.366804853768
# recovered batch range 1.28524, -0.164103
# batch range 1.0, 0.0
# corrupted batch range 1.34623880855, -0.261401049982
# recovered batch range 1.24358, -0.0758417
# batch range 1.0, 0.0
# corrupted batch range 1.3510641568, -0.379997558226
# recovered batch range 1.29293, -0.0801811
# batch range 1.0, 0.0
# corrupted batch range 1.35475036782, -0.343080124106
# recovered batch range 1.21354, -0.120702
# batch range 1.0, 0.0
# corrupted batch range 1.30971967423, -0.336853304344
# recovered batch range 1.22454, -0.119056
# batch range 1.0, 0.0
# corrupted batch range 1.32152330894, -0.316908769917
# recovered batch range 1.25413, -0.111034
# batch range 1.0, 0.0
# corrupted batch range 1.42930210329, -0.357562513788
# recovered batch range 1.21418, -0.240591
# batch range 1.0, 0.0
# corrupted batch range 1.38510786671, -0.296861235033
# recovered batch range 1.19154, -0.140284
# batch range 1.0, 0.0
# corrupted batch range 1.33611020028, -0.28872380622
# recovered batch range 1.17192, -0.110007
# batch range 1.0, 0.0
# corrupted batch range 1.44255687056, -0.302047993195
# recovered batch range 1.26968, -0.0620779
# batch range 1.0, 0.0
# corrupted batch range 1.35514041995, -0.331730072181
# recovered batch range 1.29534, -0.111393
# batch range 1.0, 0.0
# corrupted batch range 1.31512418232, -0.298838041968
# recovered batch range 1.20138, -0.0558787
# batch range 1.0, 0.0
# corrupted batch range 1.3488940203, -0.310206479938
# recovered batch range 1.27807, -0.114455
# batch range 1.0, 0.0
# corrupted batch range 1.35787610153, -0.395364767072
# recovered batch range 1.22681, -0.102789
# batch range 1.0, 0.0
# corrupted batch range 1.34862107232, -0.344134476495
# recovered batch range 1.19913, -0.113588
# batch range 1.0, 0.0
# corrupted batch range 1.34291158586, -0.368045774389
# recovered batch range 1.20551, -0.0710149
# batch range 1.0, 0.0
# corrupted batch range 1.40060428377, -0.303309873913
# recovered batch range 1.26097, -0.0871211
# batch range 1.0, 0.0
# corrupted batch range 1.33861999644, -0.301776096722
# recovered batch range 1.23214, -0.113744
# batch range 1.0, 0.0
# corrupted batch range 1.3533657997, -0.372493412402
# recovered batch range 1.28784, -0.129667
# batch range 1.0, 0.0
# corrupted batch range 1.37672254028, -0.386406663753
# recovered batch range 1.23508, -0.134658
# batch range 1.0, 0.0
# corrupted batch range 1.33249164668, -0.330994377636
# recovered batch range 1.25665, -0.150475
# batch range 1.0, 0.0
# corrupted batch range 1.43266194108, -0.365639055946
# recovered batch range 1.27194, -0.103075
# batch range 1.0, 0.0
# corrupted batch range 1.34072780754, -0.329709227278
# recovered batch range 1.18488, -0.0729192
# batch range 1.0, 0.0
# corrupted batch range 1.38365926524, -0.404647340092
# recovered batch range 1.20803, -0.0734177
# batch range 1.0, 0.0
# corrupted batch range 1.32790368894, -0.364440858283
# recovered batch range 1.32196, -0.15387
# batch range 1.0, 0.0
# corrupted batch range 1.32661436435, -0.34846812046
# recovered batch range 1.2692, -0.132935
# batch range 1.0, 0.0
# corrupted batch range 1.41035613962, -0.347615924244
# recovered batch range 1.20217, -0.0847369
# batch range 1.0, 0.0
# corrupted batch range 1.39414677126, -0.316379934566
# recovered batch range 1.24231, -0.099689
# batch range 1.0, 0.0
# corrupted batch range 1.35509543453, -0.381864823455
# recovered batch range 1.22163, -0.105154
# 22.322299992
